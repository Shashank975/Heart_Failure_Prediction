# %%
import os
import numpy as np 
import pandas as pd
import seaborn as sns


for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/heart-failure-prediction/heart.csv

# %%
df=pd.read_csv("/kaggle/input/heart-failure-prediction/heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.shape
# Out:
# (918, 12)

# %%
for i in df.columns:
    print(i)
# Out:
# Age
# Sex
# ChestPainType
# RestingBP
# Cholesterol
# FastingBS
# RestingECG
# MaxHR
# ExerciseAngina
# Oldpeak
# ST_Slope
# HeartDisease

# %% [markdown]
# **AGE Distribution Plot**

# %%
df["Age"].unique()
# Out:
# array([40, 49, 37, 48, 54, 39, 45, 58, 42, 38, 43, 60, 36, 44, 53, 52, 51,
#        56, 41, 32, 65, 35, 59, 50, 47, 31, 46, 57, 55, 63, 66, 34, 33, 61,
#        29, 62, 28, 30, 74, 68, 72, 64, 69, 67, 73, 70, 77, 75, 76, 71])

# %%
df["Age"].nunique()
# Out:
# 50

# %%
sns.displot(df['Age'], kde = True, color = 'blue')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(df["Age"],rug=True)
# Out:
# /tmp/ipykernel_32/313692269.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],rug=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# **Resting BP**

# %%
df["RestingBP"].unique()
# Out:
# array([140, 160, 130, 138, 150, 120, 110, 136, 115, 100, 124, 113, 125,
#        145, 112, 132, 118, 170, 142, 190, 135, 180, 108, 155, 128, 106,
#         92, 200, 122,  98, 105, 133,  95,  80, 137, 185, 165, 126, 152,
#        116,   0, 144, 154, 134, 104, 139, 131, 141, 178, 146, 158, 123,
#        102,  96, 143, 172, 156, 114, 127, 101, 174,  94, 148, 117, 192,
#        129, 164])

# %%
sns.displot(df["RestingBP"],bins=50,kde=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Cholesterol**

# %%
df["Cholesterol"].unique()
# Out:
# array([289, 180, 283, 214, 195, 339, 237, 208, 207, 284, 211, 164, 204,
#        234, 273, 196, 201, 248, 267, 223, 184, 288, 215, 209, 260, 468,
#        188, 518, 167, 224, 172, 186, 254, 306, 250, 177, 227, 230, 294,
#        264, 259, 175, 318, 216, 340, 233, 205, 245, 194, 270, 213, 365,
#        342, 253, 277, 202, 297, 225, 246, 412, 265, 182, 218, 268, 163,
#        529, 100, 206, 238, 139, 263, 291, 229, 307, 210, 329, 147,  85,
#        269, 275, 179, 392, 466, 129, 241, 255, 276, 282, 338, 160, 156,
#        272, 240, 393, 161, 228, 292, 388, 166, 247, 331, 341, 243, 279,
#        198, 249, 168, 603, 159, 190, 185, 290, 212, 231, 222, 235, 320,
#        187, 266, 287, 404, 312, 251, 328, 285, 280, 192, 193, 308, 219,
#        257, 132, 226, 217, 303, 298, 256, 117, 295, 173, 315, 281, 309,
#        200, 336, 355, 326, 171, 491, 271, 274, 394, 221, 126, 305, 220,
#        242, 347, 344, 358, 169, 181,   0, 236, 203, 153, 316, 311, 252,
# ...

# %%
sns.displot(df["Cholesterol"],color="Red",kde=True,bins=50)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
c=0
for i in df["Cholesterol"]:
    if(i==0 ):
        c+=1
print(c)
# Out:
# 172

# %% [markdown]
# There are 172 people who are having 0 or less than 2mg Cholesterol.
# Low cholesterol has been linked to some serious health complications. It's a risk factor for primary intracerebral hemorrhage, which typically happens in older adults. It also carries a risk for low birth weight or premature birth in pregnant women.

# %% [markdown]
# **Maximum Heart Rate**

# %%
df["MaxHR"].unique()
# Out:
# array([172, 156,  98, 108, 122, 170, 142, 130, 120,  99, 145, 140, 137,
#        150, 166, 165, 125, 160, 164, 138, 178, 112, 118, 127, 114, 154,
#        155,  87, 148, 100, 168, 184, 121, 153, 134,  96, 174, 175, 144,
#         82, 135, 115, 128, 116,  94, 110,  92, 180, 152, 124, 106, 185,
#        139, 190, 146, 158, 132, 176, 119, 188, 162, 105,  90, 136, 167,
#        129, 102, 143, 103,  91, 126,  93, 131, 149, 123, 182, 141,  77,
#        109, 133, 179, 113, 104,  95,  72,  97, 117,  86,  63, 157,  83,
#         60,  70, 163,  67,  78,  84, 111,  80, 107, 161,  69,  88,  73,
#        159, 151, 181, 186, 177, 173, 169, 171, 147,  71, 192, 195, 194,
#        187, 202])

# %%
df["MaxHR"].nunique()
# Out:
# 119

# %%
sns.displot(df['MaxHR'], kde = True, color = 'pink')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Oldpeaks**

# %%
df["Oldpeak"].unique()
# Out:
# array([ 0. ,  1. ,  1.5,  2. ,  3. ,  4. ,  0.5,  2.5,  5. ,  0.8,  0.7,
#         1.4,  2.1,  0.4,  0.2,  1.7,  2.2,  0.1,  1.6,  1.3,  0.3,  1.8,
#         2.6, -0.9,  2.8, -2.6, -1.5, -0.1,  0.9,  1.1,  2.4, -1. , -1.1,
#        -0.7, -0.8,  3.7,  1.2, -0.5, -2. ,  1.9,  3.5,  0.6,  3.1,  2.3,
#         3.4,  3.6,  4.2,  3.2,  5.6,  3.8,  2.9,  6.2,  4.4])

# %%
df["Oldpeak"].nunique()
# Out:
# 53

# %%
sns.displot(df['Oldpeak'], kde = True, color = 'blue')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# M-> Male ,F->Females
df["Sex"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
m=0
f=0
for i in df["Sex"]:
    if(i=="M"):
        m+=1
    elif(i=="F"):
        f+=1
print("There are Total Male :",m)
print("There are Total Female :",f)
# Out:
# There are Total Male : 725
# There are Total Female : 193

# %%
df.groupby("Sex").size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
df.groupby("Sex").size().plot(kind="pie",autopct="%0.01f",explode=[0,0.2],shadow=True)
# Out:
# <Axes: >

# %% [markdown]
# **ChestPainType**

# %%
df["ChestPainType"].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df["ChestPainType"].nunique()
# Out:
# 4

# %%
df.groupby("ChestPainType").size().plot(kind='pie',autopct="%0.01f",explode=[0.1,0,0,0.2],shadow=True)
# Out:
# <Axes: >

# %% [markdown]
# Atypical chest pain is a kind of chest pain that's not typical or classic. Because there are many causes of atypical chest pain, treatments vary widely. You should always contact a healthcare provider about atypical chest pain.

# %% [markdown]
# **RestingECG**

# %%
df["RestingECG"].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df["RestingECG"].nunique()
# Out:
# 3

# %%
df.groupby("RestingECG").size().plot(kind='pie',autopct="%0.01f",explode=[0,0.2,0],shadow=True)
# Out:
# <Axes: >

# %% [markdown]
# **ST Slope**

# %%
df["ST_Slope"].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df["ST_Slope"].nunique()
# Out:
# 3

# %%
df.groupby("ST_Slope").size().plot(kind='pie',autopct="%0.01f",explode=[0.3,0,0],shadow=True)
# Out:
# <Axes: >

# %% [markdown]
# **HeartProblem**

# %%
df["HeartDisease"].unique()
# Out:
# array([0, 1])

# %%
df["HeartDisease"].nunique()
# Out:
# 2

# %%
h=0
nh=0
for i in df["HeartDisease"]:
    if(i==1):
        h+=1
    elif(i==0):
        nh+=1
print("People Having Heart Problem are : ",h)
print("People not Having Heart Problem are : ",nh)
# Out:
# People Having Heart Problem are :  508
# People not Having Heart Problem are :  410

# %%
df.groupby("HeartDisease").size().plot(kind='pie',autopct="%0.01f",explode=[0,0.1],shadow=True)
# Out:
# <Axes: >

# %%
df.groupby("HeartDisease").size().plot(kind='barh')
# Out:
# <Axes: ylabel='HeartDisease'>

# %% [markdown]
# **Violin Plot**

# %%
sns.violinplot(y=df["Sex"],x=df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %% [markdown]
# 1. There are more Numbers of Females Who are not having Heart Disease.
# 2. There are more Numbers of Males Who are  having Heart Disease.

# %%
sns.violinplot(y=df["Cholesterol"],x=df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# 1. There are most of the people who is having 0 or low Cholestrole having heart disease.
# 2. There are most of the people who is  having 200 to 300 Cholestrole not having heart disease.
# 3. But there are also  some people who is  having 200 to 300 Cholestrole having heart disease.

# %%
sns.violinplot(y=df["Age"],x=df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %% [markdown]
# 1. Most of people whoes are age more than 55 are having heart Disease.
# 2. Most of people whoes are age less than 55 are having not  heart Disease.

# %%
sns.violinplot(x=df["ChestPainType"],y=df["HeartDisease"])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='HeartDisease'>

# %% [markdown]
# 1. Those people who are having ASY type chest pain are having having Haeart Disease.

# %%
sns.violinplot(y=df["MaxHR"],x=df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='MaxHR'>

# %% [markdown]
# 1. Those people whoes Maxium Heart is between 85 to 150 are having Heart Disease.
# 2. Those people whose heart Rate is Between 100 to 175 are not having Heart Disase.

# %%
df.head(1)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0

# %%
sns.violinplot(y=df["ST_Slope"],x=df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='ST_Slope'>

# %% [markdown]
# 1. Those people who is having Down or Flat Slope are Having Disease.
# 2. Those people who is having UP Slope are  not Having Disease or very Chances.

# %% [markdown]
# **Correlation(HeatMap)**

# %%
df.corr()
# Out:
# /tmp/ipykernel_32/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# ...

# %%
sns.heatmap(df.corr())
# Out:
# /tmp/ipykernel_32/58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# * Accprding the Heat Map :-
# 1. Those people Who are having High Cholestrole and Mximum Heart Rate Are less Chances of having Heart Disease.
# 2. This is Just Showing the oposite of the above Calculations.

# %% [markdown]
# **jointPlot**

# %%
sns.jointplot(x = 'Age' , y = 'MaxHR', data = df, kind = 'reg')

# %% [markdown]
# 1. We can see that as the Age Increases the Haert Rate is Decreases.

# %%
sns.jointplot(x = 'Age' , y = 'MaxHR', data = df, kind = 'hex')

# %% [markdown]
# 1. Between the age 55 the heart is between 120 and 160 and as we down Haert .Rate is Decreases

# %% [markdown]
# **Pair Plot**

# %%
sns.pairplot(df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
